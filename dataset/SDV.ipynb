# %%
# Install SDV with multi-table support
# !pip install sdv
# !pip install sdv[multi-table]

import pandas as pd
import numpy as np
from faker import Faker
import random
from sdv.metadata import MultiTableMetadata
from sdv.multi_table import HMASynthesizer
# Out:
# Requirement already satisfied: sdv in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.22.1)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (1.38.36)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (1.38.36)
# Requirement already satisfied: cloudpickle>=2.1.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (1.26.3)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (2.2.0)
# Requirement already satisfied: tqdm>=4.29 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (4.67.1)
# Requirement already satisfied: copulas>=0.12.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (0.12.3)
# Requirement already satisfied: ctgan>=0.11.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (0.11.0)
# Requirement already satisfied: deepecho>=0.7.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (0.7.0)
# Requirement already satisfied: rdt>=1.17.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (1.17.0)
# Requirement already satisfied: sdmetrics>=0.21.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (0.21.0)
# Requirement already satisfied: platformdirs>=4.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (4.2.2)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv) (6.0.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3<2.0.0,>=1.28->sdv) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from botocore<2.0.0,>=1.31->sdv) (2.4.0)
# Requirement already satisfied: plotly>=5.10.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from copulas>=0.12.1->sdv) (6.1.2)
# Requirement already satisfied: scipy>=1.9.2 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from copulas>=0.12.1->sdv) (1.14.1)
# Requirement already satisfied: torch>=2.0.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ctgan>=0.11.0->sdv) (2.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.5.0->sdv) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.5.0->sdv) (2024.1)
# Requirement already satisfied: scikit-learn>=1.1.3 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rdt>=1.17.0->sdv) (1.4.0)
# Requirement already satisfied: Faker>=17 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rdt>=1.17.0->sdv) (37.4.0)
# Requirement already satisfied: colorama in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.29->sdv) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (1.41.0)
# Requirement already satisfied: packaging in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (3.5.0)
# Requirement already satisfied: filelock in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (4.13.2)
# Requirement already satisfied: sympy in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (1.14.0)
# Requirement already satisfied: networkx in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.5)
# Requirement already satisfied: jinja2 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2025.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->torch>=2.0.0->ctgan>=0.11.0->sdv) (1.3.0)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\sneha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: sdv[multi-table] in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.22.1)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (1.38.36)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (1.38.36)
# Requirement already satisfied: cloudpickle>=2.1.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (1.26.3)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (2.2.0)
# Requirement already satisfied: tqdm>=4.29 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (4.67.1)
# Requirement already satisfied: copulas>=0.12.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (0.12.3)
# Requirement already satisfied: ctgan>=0.11.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (0.11.0)
# Requirement already satisfied: deepecho>=0.7.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (0.7.0)
# Requirement already satisfied: rdt>=1.17.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (1.17.0)
# Requirement already satisfied: sdmetrics>=0.21.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (0.21.0)
# Requirement already satisfied: platformdirs>=4.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (4.2.2)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sdv[multi-table]) (6.0.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3<2.0.0,>=1.28->sdv[multi-table]) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3<2.0.0,>=1.28->sdv[multi-table]) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from botocore<2.0.0,>=1.31->sdv[multi-table]) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from botocore<2.0.0,>=1.31->sdv[multi-table]) (2.4.0)
# Requirement already satisfied: plotly>=5.10.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from copulas>=0.12.1->sdv[multi-table]) (6.1.2)
# Requirement already satisfied: scipy>=1.9.2 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from copulas>=0.12.1->sdv[multi-table]) (1.14.1)
# Requirement already satisfied: torch>=2.0.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ctgan>=0.11.0->sdv[multi-table]) (2.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.5.0->sdv[multi-table]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.5.0->sdv[multi-table]) (2024.1)
# Requirement already satisfied: scikit-learn>=1.1.3 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rdt>=1.17.0->sdv[multi-table]) (1.4.0)
# Requirement already satisfied: Faker>=17 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rdt>=1.17.0->sdv[multi-table]) (37.4.0)
# Requirement already satisfied: colorama in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.29->sdv[multi-table]) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv[multi-table]) (1.41.0)
# Requirement already satisfied: packaging in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv[multi-table]) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv[multi-table]) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv[multi-table]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv[multi-table]) (3.5.0)
# Requirement already satisfied: filelock in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv[multi-table]) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv[multi-table]) (4.13.2)
# Requirement already satisfied: sympy in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv[multi-table]) (1.14.0)
# Requirement already satisfied: networkx in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv[multi-table]) (3.5)
# Requirement already satisfied: jinja2 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv[multi-table]) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv[multi-table]) (2025.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv[multi-table]) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sneha\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->torch>=2.0.0->ctgan>=0.11.0->sdv[multi-table]) (1.3.0)
# WARNING: sdv 1.22.1 does not provide the extra 'multi-table'
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\sneha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Initialize Faker and seed
fake = Faker()
np.random.seed(42)

# 🧍 Patients Table
patients = pd.DataFrame({
    'patient_id': [f'P{i}' for i in range(100)],
    'gender': np.random.choice(['M', 'F'], size=100),
    'age': np.random.randint(18, 90, size=100),
    'location': np.random.choice(['Newark', 'Jersey City', 'Clifton', 'Englewood'], size=100)
})

# 🏥 Providers Table
providers = pd.DataFrame({
    'provider_id': [f'D{i}' for i in range(20)],
    'specialty': np.random.choice(['Cardiology', 'Oncology', 'General Practice', 'Pediatrics'], size=20),
    'location': np.random.choice(['Newark', 'Jersey City', 'Clifton', 'Englewood'], size=20),
    'years_of_experience': np.random.randint(1, 40, size=20)
})

# 💉 Procedures Table
procedures = pd.DataFrame({
    'procedure_code': [f'PC{i}' for i in range(50)],
    'description': [fake.catch_phrase() for _ in range(50)],
    'typical_cost': np.round(np.random.uniform(100, 10000, size=50), 2)
})

# 📄 Claims Table
claims = pd.DataFrame({
    'claim_id': [f'C{i}' for i in range(500)],
    'patient_id': np.random.choice(patients['patient_id'], size=500),
    'provider_id': np.random.choice(providers['provider_id'], size=500),
    'procedure_code': np.random.choice(procedures['procedure_code'], size=500),
    'diagnosis_code': np.random.choice(['D001', 'D002', 'D003', 'D004', 'D005'], size=500),
    'claim_amount': np.round(np.random.uniform(100, 15000, size=500), 2),
    'claim_date': pd.to_datetime('2024-01-01') + pd.to_timedelta(np.random.randint(0, 365, size=500), unit='D')
})




# Convert string columns to ensure consistency
for df in [patients, providers, procedures, claims]:
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].astype(str)

real_data = {
    'patients': patients,
    'providers': providers,
    'procedures': procedures,
    'claims': claims
}

# 🚧 Build metadata with correct signature
metadata = MultiTableMetadata()
metadata.detect_from_dataframes(
    data=real_data
)

# ✅ Align formats for IDs
metadata.update_column('procedures', 'procedure_code', sdtype='id', regex_format=r'PC\d+')
metadata.update_column('claims', 'procedure_code', sdtype='id', regex_format=r'PC\d+')
metadata.update_column('claims', 'claim_id', sdtype='id', regex_format=r'C\d+')
metadata.update_column('patients', 'patient_id', sdtype='id', regex_format=r'P\d+')
metadata.update_column('providers', 'provider_id', sdtype='id', regex_format=r'D\d+')

# Validate metadata and data
metadata.validate()
metadata.validate_data(real_data)

# ⚙️ Fit & sample
synth = HMASynthesizer(metadata)
synth.fit(real_data)
synthetic_data = synth.sample()

# 🎯 Inspect
print(synthetic_data['procedures'].procedure_code.head())
print(synthetic_data['claims'].procedure_code.head())
# Out:
# C:\Users\sneha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sdv\multi_table\base.py:110: FutureWarning:
#
# The 'MultiTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#
# C:\Users\sneha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sdv\multi_table\base.py:102: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# Preprocess Tables: 100%|██████████| 4/4 [00:00<00:00,  7.25it/s]
# Learning relationships:
# (1/3) Tables 'patients' and 'claims' ('patient_id'): 100%|██████████| 100/100 [00:07<00:00, 13.35it/s]
# (2/3) Tables 'providers' and 'claims' ('provider_id'): 100%|██████████| 20/20 [00:01<00:00, 13.13it/s]
# (3/3) Tables 'procedures' and 'claims' ('procedure_code'): 100%|██████████| 50/50 [00:04<00:00, 11.86it/s]
# Modeling Tables: 100%|██████████| 4/4 [00:00<00:00,  9.07it/s]
# 0    PC34
# 1    PC06
# 2    PC11
# 3    PC39
# 4    PC21
# Name: procedure_code, dtype: object
# 0    PC31
# 1    PC31
# 2    PC20
# 3    PC20
# 4    PC20
# Name: procedure_code, dtype: object

# %%
synthetic_data['patients'].head()
# Out:
#   patient_id gender  age     location
# 0        P06      F   37    Englewood
# 1        P85      M   77       Newark
# 2        P23      F   49       Newark
# 3         P4      M   36  Jersey City
# 4        P71      M   56  Jersey City

# %%
synthetic_data['providers'].head()
# Out:
#   provider_id         specialty     location  years_of_experience
# 0          D2          Oncology    Englewood                   20
# 1         D00        Cardiology    Englewood                   31
# 2          D0  General Practice    Englewood                   15
# 3          D9        Cardiology      Clifton                   24
# 4         D03          Oncology  Jersey City                   30

# %%
synthetic_data['procedures'].head()
# Out:
#   procedure_code                              description  typical_cost
# 0           PC34        Function-based maximized leverage       7548.75
# 1           PC06     Self-enabling leadingedge neural-net       8409.80
# 2           PC11  Multi-channeled 3rdgeneration framework       5376.84
# 3           PC39         Stand-alone zero-defect approach       9736.63
# 4           PC21               Progressive 24/7 moderator       7524.22

# %%
synthetic_data['claims'].head()
# Out:
#   claim_id patient_id provider_id procedure_code diagnosis_code  claim_amount  \
# 0       C2        P06         D04           PC31           D002        147.95
# 1       C4        P06         D07           PC31           D002        147.95
# 2       C0        P06          D3           PC20           D002        147.95
# 3       C1        P06          D2           PC20           D002        147.95
# 4       C5        P06         D04           PC20           D002        147.95
#
#   claim_date
# 0 2024-08-10
# 1 2024-10-07
# 2 2024-06-15
# 3 2024-07-23
# 4 2024-10-07

# %%
for procedures, df in synthetic_data.items():
    df.to_csv(f"synthetic_{procedures}.csv", index=False)

# %%
for providers, df in synthetic_data.items():
    df.to_csv(f"synthetic_{providers}.csv", index=False)

# %%
for claims, df in synthetic_data.items():
    df.to_csv(f"synthetic_{claims}.csv", index=False)

# %%
for patients, df in synthetic_data.items():
    df.to_csv(f"synthetic_{patients}.csv", index=False)
